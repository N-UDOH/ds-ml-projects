# %% [markdown]
# # PROJECT TITLE: Sale Prediction from existing customer using Logistic Regression

# %% [markdown]
# ## About the Project
# In this project, I developed and worked with a custom-built dataset containing 400 entries. The dataset includes three key features: age, salary, and status (indicating whether the customer will make a purchase or not). The goal of this project is to leverage Logistic Regression, a widely used classification algorithm, to predict whether a customer is likely to make a purchase based on their profile.
# ## Goal:
# To determine the significant relationship between a customer's age, salary, and their likelihood of making a purchase, as well as to predict future purchase behavior using Logistic Regression
# ## Dataset Details:
# * Age: Represents the customer's age in years.
# * Salary: Represents the customer's annual salary.
# * Status: A binary column indicating whether the customer will make a purchase (1 for "will buy" and 0 for "won't buy").
# ## Methodologies:
# * Data Preparation: I Organized the dataset to ensure it is properly structured for analysis
# * Data Cleaning and Preprocessing: I Used the pandas library to handle missing values, check for outliers, and normalize numeric variables to prepare the data for modeling
# * Exploratory Data Analysis (EDA):I Visualized data trends using scatter plots, histograms, and box plots to examine the relationships between age, salary, and purchase status.
# * Modeling: Logistic Regression was applied to train a predictive model that identifies the probability of a customer making a purchase based on their age and salary.
#
# ## Evaluation:
# * The model performance was accessed using metrics confusion matrix.
# ## Skills Developed:
# * Understanding of Python libraries like pandas, matplotlib, and seaborn for data cleaning, analysis, and visualization.
# * Practical experience in applying Logistic Regression for binary classification problems.
# * Insights into feature engineering and the importance of preprocessing for effective model training.
# * Proficiency in evaluating classification models using appropriate metrics.

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import confusion_matrix, accuracy_score

# %%
data=r"C:\Users\UDOH\Desktop\ALL PANTECH\3_AdSalePrediction_LR_Classifier\3_AdSalePrediction_LR_Classifier\DigitalAd_dataset.csv"

# %%
df = pd.read_csv(data)

# %%
df.head()
# Out:
#    Age  Salary  Status
# 0   18   82000       0
# 1   29   80000       0
# 2   47   25000       1
# 3   45   26000       1
# 4   46   28000       1

# %%
df.shape
# Out:
# (400, 3)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 400 entries, 0 to 399
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Age     400 non-null    int64
#  1   Salary  400 non-null    int64
#  2   Status  400 non-null    int64
# dtypes: int64(3)
# memory usage: 9.5 KB

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns


# Define the custom palette
custom_palette = {0: 'red', 1: 'green'}

# Scatter Plot: Age vs Salary with Status
plt.figure(figsize=(8, 6))
sns.scatterplot(data=df, x='Age', y='Salary', hue='Status', palette=custom_palette, alpha=0.8)
plt.title('Scatter Plot: Age vs Salary (Colored by Status)', fontsize=14)
plt.xlabel('Age(years)', fontsize=12)
plt.ylabel('Salary(Naira)', fontsize=12)
# Customize the legend
handles, labels = plt.gca().get_legend_handles_labels()
plt.legend(handles=handles, labels=['Will Not Buy (0) - Red', 'Will Buy (1) - Green'], title='Status')
plt.grid(True)
plt.show()

# %%
# Histogram for Age and Status
plt.figure(figsize=(8, 6))
sns.histplot(data=df, x='Age', hue='Status', palette={0: 'red', 1: 'blue'}, bins=20, alpha=0.7)
plt.title('Histogram: Age Distribution by Status', fontsize=14)
plt.xlabel('Age(years)', fontsize=12)
plt.ylabel('Salary(Naira)', fontsize=12)
plt.legend(title='Status', labels=['Will Not Buy (0)', 'Will Buy (1)'])
plt.grid(True)
plt.show()

# %% [markdown]
#  ### To segregate the dataset into X(input/independent) and Y(output/dependent)

# %%
x = df.iloc[:, :-1].values
x
# Out:
# array([[    18,  82000],
#        [    29,  80000],
#        [    47,  25000],
#        [    45,  26000],
#        [    46,  28000],
#        [    48,  29000],
#        [    45,  22000],
#        [    47,  49000],
#        [    48,  41000],
#        [    45,  22000],
#        [    46,  23000],
#        [    47,  20000],
#        [    49,  28000],
#        [    47,  30000],
#        [    29,  43000],
#        [    31,  18000],
#        [    31,  74000],
#        [    27, 137000],
#        [    21,  16000],
#        [    28,  44000],
#        [    27,  90000],
#        [    35,  27000],
#        [    33,  28000],
#        [    30,  49000],
#        [    26,  72000],
#        [    27,  31000],
#        [    27,  17000],
#        [    33,  51000],
#        [    35, 108000],
#        [    30,  15000],
#        [    28,  84000],
#        [    23,  20000],
#        [    25,  79000],
#        [    27,  54000],
#        [    30, 135000],
#        [    31,  89000],
#        [    24,  32000],
# ...

# %%
Y = df.iloc[:,-1].values

# %%
#Segregating dataset into Train and Test
x_train, x_test, y_train, y_test = train_test_split(X, Y, test_size=0.25, random_state=0)

# %%
# Feature scaling: making all the features of X to be the same ie Age and Salary. DOnt touch Y
#we scale our data to make all the features contribute equally to the result
#Fit_transform-fit method is calculating the mean and variance of each of the
#features present in our data
#Transform- Transform method is transforming all the features using the mean and variance

sc = StandardScaler()
x_train = sc.fit_transform(x_train)
x_test = sc.transform(x_test)

# %%
# Training the model
model = LogisticRegression(random_state=0)
model.fit(x_train, y_train)
# Out:
# LogisticRegression(random_state=0)

# %%
# age = int(input("Enter the age of the new customer: "))
salary = int(input("Enter the salary of the new customer: "))

# Create a list with the new customer's data
new_customer= [[age, salary]]

# Make predictions using the trained model
result = model.predict(sc.transform(new_customer))
print(result)
if result == 1:
    print("Customer will buy")
else:
    print("Customer Won't buy")

# %%
# Prediction for all test data
y_pred = model.predict(x_test)
print(y_pred)

# %%
#Evaluating model Using Confusion Matrix
cm = confusion_matrix(y_test, y_pred)
print(cm)

print("Accuracy of the model: {0}%".format(accuracy_score(y_test, y_pred)*100))

# %% [markdown]
# ## Conclusion:
# * This project demonstrates the practical use of machine learning in analyzing customer data to make data-driven sales predictions. It highlights how Age and financial data can be utilized to understand customer behavior and improve sales strategies.
